# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv("titanic _01.csv")

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
## cabin not equal to "NaN"

data1["Cabin"] != "NaN"
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 886    True
# 887    True
# 888    True
# 889    True
# 890    True
# Name: Cabin, Length: 891, dtype: bool

# %%
## cabin  not equal to "NaN"

data1[data1["Cabin"].isnull() != True]
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
## cabin  equal to "NaN"

data1[data1["Cabin"].isnull() == True]
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 0              1         0       3                   Braund, Mr. Owen Harris  \
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
## Add "Name _new in columns and copy a "Sex" data into the new columns:

data1["Name_new"] = data1["Sex"]

# %%
data1
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
## Add Age and Pc lass in one columns :

data1["Age_Pclass"] = data1 ["Age"] + data1 ["Pclass"]

# %%
data1
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
## Permanently delete a dataset :  Axis=1 , inplace=True :

data1.drop('Name_new',axis=1,inplace=True)

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_Pclass
# 0      0         A/5 21171   7.2500   NaN        S        25.0
# 1      0          PC 17599  71.2833   C85        C        39.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        29.0
# ...

# %% [markdown]
# ### Explain :
#
# ![image.png](attachment:image.png)

# %%
data1.drop('Age_Pclass',axis=1,inplace=True)

# %%
data1
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
## Fetch Row NO:01
## iloc is a indexed-based selecting

data1.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
## Fetch Row NO:01
## loc is a label based data selecting

data1.loc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
data1.head(7)
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
## Fetch a dataset starting from INDEX [2] to [6] : 

data1.loc[2:6]
# Out:
#    PassengerId  Survived  Pclass
# 2            3         1       3  \
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                            Name     Sex   Age  SibSp  Parch
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
# 6                       McCarthy, Mr. Timothy J    male  54.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q
# 6             17463  51.8625   E46        S

# %%
## Fetch a dataset starting from INDEX [101] to [106] and column "Survived" and "Pclass": 

data1.loc[101:106]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex
# 101          102         0       3  Petroff, Mr. Pastcho ("Pentcho")    male  \
# 102          103         0       1         White, Mr. Richard Frasar    male
# 103          104         0       3        Johansson, Mr. Gustaf Joel    male
# 104          105         0       3    Gustafsson, Mr. Anders Vilhelm    male
# 105          106         0       3             Mionoff, Mr. Stoytcho    male
# 106          107         1       3  Salkjelsvik, Miss. Anna Kristine  female
#
#       Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 101   NaN      0      0   349215   7.8958   NaN        S
# 102  21.0      0      1    35281  77.2875   D26        S
# 103  33.0      0      0     7540   8.6542   NaN        S
# 104  37.0      2      0  3101276   7.9250   NaN        S
# 105  28.0      0      0   349207   7.8958   NaN        S
# 106  21.0      0      0   343120   7.6500   NaN        S

# %%
data1["Age"].isnull() != False
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
## Age not equal to "NaN"

data1[data1["Age"].isnull() != False]
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 5              6         0       3                          Moran, Mr. James  \
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
data1.loc[2:5]
# Out:
#    PassengerId  Survived  Pclass
# 2            3         1       3  \
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q

# %% [markdown]
# - ![image.png](attachment:image.png)

# %%
## loc() : iloc works with index and name 

data1.loc[[3,4] , ["Fare","Cabin","Embarked"]]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
## Error with iloc() : iloc works with diffult indexes

data1.iloc[[3,4] , ["Fare","Cabin","Embarked"]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 3
#       1 ## Error with iloc() : iloc works with diffult indexes
# ----> 3 data1.iloc[[3,4] , ["Fare","Cabin","Embarked"]]
#
# File c:\Users\Farshid Hesami\anaconda3\envs\env1\lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File c:\Users\Farshid Hesami\anaconda3\envs\env1\lib\site-packages\pandas\core\indexing.py:1594, in _iLocIndexer._getitem_tuple(self, tup)
#    1593 def _getitem_tuple(self, tup: tuple):
# -> 1594     tup = self._validate_tuple_indexer(tup)
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data1.iloc[[2,3] , [9,10,11]]
# Out:
#      Fare Cabin Embarked
# 2   7.925   NaN        S
# 3  53.100  C123        S

# %%
data1.loc[101:106,["Survived","Pclass","Age"] ]
# Out:
#      Survived  Pclass   Age
# 101         0       3   NaN
# 102         0       1  21.0
# 103         0       3  33.0
# 104         0       3  37.0
# 105         0       3  28.0
# 106         1       3  21.0

# %%
## Filltred "PassengerId" and "Pclass" for all Rows 
   ## using iloc and loc
   
data1.loc[ : ,["PassengerId","Pclass"] ]
# Out:
#      PassengerId  Pclass
# 0              1       3
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [891 rows x 2 columns]

# %%
data1.iloc[ : ,[0,2] ]
# Out:
#      PassengerId  Pclass
# 0              1       3
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [891 rows x 2 columns]

# %%
data1.loc[3:5,["PassengerId","Survived","Pclass"] ]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3

# %%
# Age grather than 35 :

data1[data1["Age"] > 35]
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1=data1.iloc[1:5,[2,3,4,5,9,10]]

# %%
data1
# Out:
#    Pclass                                               Name     Sex   Age
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  \
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#       Fare Cabin
# 1  71.2833   C85
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN

# %% [markdown]
# ## set_index() in pandas

# %%
## Change a coulum name to index name :

data1.set_index("Name")
# Out:
#                                                     Pclass     Sex   Age
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0  \
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN

# %%
data1.set_index("Name" ,inplace=True )

# %%
data1
# Out:
#                                                     Pclass     Sex   Age
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0  \
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN

# %% [markdown]
# ## Change a coulum name to index name :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Difference between .dropna vs .drop in pandas

# %%
## Drap all the records we have "NaN" values in Row.-----------> (None "NaN in excel sheet ")
    ## Dropping All Rows with Missing Values

data1.dropna(axis=0)
# Out:
#                                                     Pclass     Sex   Age
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0  \
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123

# %%
## Check Column and delete "NaN" missing data:
    ## Dropping All Columns with Missing Values

data1.dropna(axis=1)
# Out:
#                                                     Pclass     Sex   Age
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0  \
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833
# Heikkinen, Miss. Laina                               7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000
# Allen, Mr. William Henry                             8.0500

# %%
## Dropping Rows or Columns if all the Values are Null :

data1.dropna(how='all', axis=1)
# Out:
#                                                     Pclass     Sex   Age
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0  \
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN

# %%
## thresh=2 ---------> means at least 2 "NaN" value  
## thresh=3 ---------> means at least 3 "NaN" value
## thresh=4 ---------> means at least 4 "NaN" value

data1.dropna(axis=1,thresh=3)
# Out:
#                                                     Pclass     Sex   Age
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0  \
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833
# Heikkinen, Miss. Laina                               7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000
# Allen, Mr. William Henry                             8.0500

# %% [markdown]
# ### Explain :
# ![image.png](attachment:image.png)

# %%
data1.dropna(axis=1,thresh=4)
# Out:
#                                                     Pclass     Sex   Age
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0  \
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833
# Heikkinen, Miss. Laina                               7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000
# Allen, Mr. William Henry                             8.0500

# %%
data1
# Out:
#                                                     Pclass     Sex   Age
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0  \
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN

# %% [markdown]
#  #### What does Fillna () mean? You can use the fillna() function to replace NaN values in a pandas DataFrame.
#
# #### Insted of "NaN" add "farshid"

# %%
data1.fillna("Farshid")
# Out:
#                                                     Pclass     Sex   Age
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0  \
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare    Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833      C85
# Heikkinen, Miss. Laina                               7.9250  Farshid
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000     C123
# Allen, Mr. William Henry                             8.0500  Farshid

# %%
data1.fillna(data1["Age"].mean())
# Out:
#                                                     Pclass     Sex   Age
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0  \
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250  33.5
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500  33.5

# %%
## how many "female" and "male" we have ....(read a data in group)
     ## Group DataFrame using a mapper or by a Series of columns.

data1.groupby("Sex").count()
# Out:
#         Pclass  Age  Fare  Cabin
# Sex
# female       3    3     3      2
# male         1    1     1      0

# %% [markdown]
# #### data1.groupby("Age").mean()
#
# #### Error appear in VScode but in jupyterLab working

# %%
data1.groupby("Age").count()
# Out:
#       Pclass  Sex  Fare  Cabin
# Age
# 26.0       1    1     1      0
# 35.0       2    2     2      1
# 38.0       1    1     1      1

# %% [markdown]
# #### object file : An object is a string in pandas so it performs a string operation instead of a mathematical one.
# #### "Cabin" and "Sex" is a object.

# %%
data1.dtypes
# Out:
# Pclass      int64
# Sex        object
# Age       float64
# Fare      float64
# Cabin      object
# dtype: object

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Cumings, Mrs. John Bradley (Florence Briggs Thayer) to Allen, Mr. William Henry
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  4 non-null      int64
#  1   Sex     4 non-null      object
#  2   Age     4 non-null      float64
#  3   Fare    4 non-null      float64
#  4   Cabin   2 non-null      object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 192.0+ bytes

# %%
## what is Total "Fare" of "female" and "male" ???????

data1.groupby("Sex").sum()["Fare"]
# Out:
# Sex
# female    132.3083
# male        8.0500
# Name: Fare, dtype: float64

# %%
data1.groupby("Sex").sum()["Age"]
# Out:
# Sex
# female    99.0
# male      35.0
# Name: Age, dtype: float64

# %% [markdown]
# ### Data22 & data11 :

# %%
data22=pd.read_csv("titanic _01.csv")

# %%
data11 = pd.read_csv("titanic _01.csv")

# %%
data22.head(10)
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data11.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 881          882         0       3                        Markun, Mr. Johann  \
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# #### concat01

# %%
concat01 = data11.iloc[881:886 ,0:5]

# %%
concat01
# Out:
#      PassengerId  Survived  Pclass                                  Name
# 881          882         0       3                    Markun, Mr. Johann  \
# 882          883         0       3          Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2         Banfield, Mr. Frederick James
# 884          885         0       3                Sutehall, Mr. Henry Jr
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
#
#         Sex
# 881    male
# 882  female
# 883    male
# 884    male
# 885  female

# %% [markdown]
# #### concat02

# %%
concat02 = data22.iloc[1:6 ,0:5]

# %%
concat02
# Out:
#    PassengerId  Survived  Pclass
# 1            2         1       1  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# 5                                   Moran, Mr. James    male

# %% [markdown]
# ### Mearge concat01 and concat02

# %%
pd.concat([concat01,concat02])
# Out:
#      PassengerId  Survived  Pclass
# 881          882         0       3  \
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
#
#                                                   Name     Sex
# 881                                 Markun, Mr. Johann    male
# 882                       Dahlberg, Miss. Gerda Ulrika  female
# 883                      Banfield, Mr. Frederick James    male
# 884                             Sutehall, Mr. Henry Jr    male
# 885               Rice, Mrs. William (Margaret Norton)  female
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# ...

# %% [markdown]
# #### Concatenating 2 DataFrames horizontally with axis = 1.

# %%
pd.concat([concat01,concat02] ,axis=1)
# Out:
#      PassengerId  Survived  Pclass                                  Name
# 881        882.0       0.0     3.0                    Markun, Mr. Johann  \
# 882        883.0       0.0     3.0          Dahlberg, Miss. Gerda Ulrika
# 883        884.0       0.0     2.0         Banfield, Mr. Frederick James
# 884        885.0       0.0     3.0                Sutehall, Mr. Henry Jr
# 885        886.0       0.0     3.0  Rice, Mrs. William (Margaret Norton)
# 1            NaN       NaN     NaN                                   NaN
# 2            NaN       NaN     NaN                                   NaN
# 3            NaN       NaN     NaN                                   NaN
# 4            NaN       NaN     NaN                                   NaN
# 5            NaN       NaN     NaN                                   NaN
#
#         Sex  PassengerId  Survived  Pclass
# 881    male          NaN       NaN     NaN  \
# 882  female          NaN       NaN     NaN
# ...

# %%
pd.concat([concat01,concat02] ,axis=0)
# Out:
#      PassengerId  Survived  Pclass
# 881          882         0       3  \
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
#
#                                                   Name     Sex
# 881                                 Markun, Mr. Johann    male
# 882                       Dahlberg, Miss. Gerda Ulrika  female
# 883                      Banfield, Mr. Frederick James    male
# 884                             Sutehall, Mr. Henry Jr    male
# 885               Rice, Mrs. William (Margaret Norton)  female
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# ...

# %% [markdown]
# ### Manipulate some DataSet in column

# %%
data1
# Out:
#                                                     Pclass     Sex   Age
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0  \
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin  New
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85    1
# Heikkinen, Miss. Laina                               7.9250   NaN    3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123    1
# Allen, Mr. William Henry                             8.0500   NaN    3

# %%
### divided Pclass/3 :

data1['Pclass/3'] = data1["Pclass"]

# %%
data1
# Out:
#                                                     Pclass     Sex   Age
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0  \
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin  New
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85    1  \
# Heikkinen, Miss. Laina                               7.9250   NaN    3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123    1
# Allen, Mr. William Henry                             8.0500   NaN    3
#
#                                                     Pclass/3
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1
# Heikkinen, Miss. Laina                                     3
# ...

# %% [markdown]
# ###  "drop" single columns :

# %%
data1.drop(["New"], axis = 1)
# Out:
#                                                     Pclass     Sex   Age
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0  \
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin  Pclass/3
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85         1
# Heikkinen, Miss. Laina                               7.9250   NaN         3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123         1
# Allen, Mr. William Henry                             8.0500   NaN         3

# %%
data1['Pclass/3']
# Out:
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    1
# Heikkinen, Miss. Laina                                 3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           1
# Allen, Mr. William Henry                               3
# Name: Pclass/3, dtype: int64

# %% [markdown]
# #### The apply() method :
#    -  allows you to apply a function along one of the axis of the DataFrame, default 0, which is the index (row) axis.
#
# #### apply() can be used with python lambda to execute expression.
#
# - A lambda function in python is a small anonymous function that can take any number of arguments and execute an expression.
# - In this article I will explain how to use a pandas DataFrame.apply() with lambda by examples.
# - lambda expressions are utilized to construct anonymous functions. You can create one by using the lambda keyword.
#     - .apply(lambda x : x + 10)

# %%
data1['Pclass/3'] = data1["Pclass"].apply(lambda x : x/3)

# %%
data1
# Out:
#                                                     Pclass     Sex   Age
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0  \
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin  New
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85    1  \
# Heikkinen, Miss. Laina                               7.9250   NaN    3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123    1
# Allen, Mr. William Henry                             8.0500   NaN    3
#
#                                                     Pclass/3
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  0.333333
# Heikkinen, Miss. Laina                              1.000000
# ...

# %% [markdown]
# #### Same result with definition "Function"

# %%
def fun1(x) :
    return x/3

# %%
data1['Pclass/3_def'] = data1["Pclass"].apply(fun1)

# %%
data1
# Out:
#                                                     Pclass     Sex   Age
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0  \
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin  New
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85    1  \
# Heikkinen, Miss. Laina                               7.9250   NaN    3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123    1
# Allen, Mr. William Henry                             8.0500   NaN    3
#
#                                                     Pclass/3  Pclass/3_def
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  0.333333      0.333333
# ...

# %%
data2
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### Remember :
#  -  . loc is typically used for label indexing and can access multiple columns, while . iloc is used for integer indexing.

# %%
data2.iloc[[1,2,3,4] , [0,1,2,3,4]]
# Out:
#    PassengerId  Survived  Pclass
# 1            2         1       1  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %% [markdown]
# #### Create a one more column and store length of a "Name"

# %%
data2['len_Name'] = data2['Name'].apply(len)

# %%
data2
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### I have "PassengerId" and "Survived" and "Pclass"------> QUestion:
#
# - Where able "PassengerId" is lesser than "3"------------------->  keep a data as it is (No changes at all)
# - Where able "PassengerId" is grather than or equal to "3"------>  Try to find out or try to updated from "logarithmic of data"

# %%
import math
def cust1(x):
    if x < 3:
        return x
    else:
        return math.log10(x)

# %%
data2["PassengerId_Filter"] = data2["PassengerId"].apply(cust1)

# %%
data2
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### Question :
#    - When ever we have a female try it to make it as "1" AND When ever we have a male try it to make it as "0"

# %%
def test2(x):
    if x == "female":
        return 1
    else:
        return 0

# %%
data2["Sex"] = data2["Sex"].apply(test2)

# %%
data2
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    0  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
data11.head(15)
# Out:
#     PassengerId  Survived  Pclass
# 0             1         0       3  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp
# 0                             Braund, Mr. Owen Harris    male  22.0      1  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# #### Question :
#    - Fill "NaN" values with the average of "Age"
#    - We have three categories-------> (A)- 0-100 dollars----->(B)- 101-199 dollars----->(C)- 200+ dollars
#    - 0-100    "A"
#    - 101-199  "B"
#    - 200+     "C"

# %% [markdown]
# ## And:(Returns True if both statements are true) ##

# %%
def test3(x):
    if x <= 100 :
        return "A"
    elif x > 100 and x < 200 :
        return "B"
    else:
        return "C"

# %%
data11["Fare_group"] = data11["Fare"].apply(test3)

# %%
data11.head(100)
# Out:
#     PassengerId  Survived  Pclass
# 0             1         0       3  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp
# 0                             Braund, Mr. Owen Harris    male  22.0      1  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...
